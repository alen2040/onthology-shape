# %%
# Install graphviz (uncomment the line below if you're using Google Colab or a fresh environment)
# !pip install graphviz

from graphviz import Digraph

# Create a new directed graph
flowchart = Digraph(comment="Development Process Flowchart", format="png")

# Define nodes (steps in the process)
flowchart.node("A", "User Research", shape="ellipse")
flowchart.node("B", "Requirements Gathering", shape="ellipse")
flowchart.node("C", "Prototyping", shape="ellipse")
flowchart.node("D", "Usability Testing", shape="ellipse")
flowchart.node("E", "Iterative Design", shape="ellipse")
flowchart.node("F", "Implementation and Development Support", shape="ellipse")

# Add edges (arrows between steps)
flowchart.edge("A", "B", arrowhead="normal")
flowchart.edge("B", "C", arrowhead="normal")
flowchart.edge("C", "D", arrowhead="normal")
flowchart.edge("D", "E", arrowhead="normal")
flowchart.edge("E", "F", arrowhead="normal")

# Add Feedback Loop (dotted line from Usability Testing back to Prototyping)
flowchart.edge("D", "C", label="Feedback Loop", style="dashed")

# Render and save the flowchart as a PNG file
flowchart.render("development_flowchart", cleanup=True)

# Display the generated diagram
from IPython.display import Image
Image("development_flowchart.png")
# Install graphviz (uncomment in Google Colab)
# !pip install graphviz

from graphviz import Digraph

# Create a new directed graph
flowchart = Digraph(comment="Shneiderman's 8 Golden Rules Flowchart", format="png")

# Define nodes (steps in the flowchart)
flowchart.node("A", "1. Strive for Consistency", shape="ellipse")
flowchart.node("B", "2. Enable Shortcuts for Frequent Users", shape="ellipse")
flowchart.node("C", "3. Offer Informative Feedback", shape="ellipse")
flowchart.node("D", "4. Design Dialogs to Yield Closure", shape="ellipse")
flowchart.node("E", "5. Prevent Errors", shape="ellipse")
flowchart.node("F", "6. Permit Easy Reversal of Actions", shape="ellipse")
flowchart.node("G", "7. Support Internal Locus of Control", shape="ellipse")
flowchart.node("H", "8. Reduce Short-Term Memory Load", shape="ellipse")

# Add edges (arrows between nodes)
flowchart.edge("A", "B")
flowchart.edge("B", "C")
flowchart.edge("C", "D")
flowchart.edge("D", "E")
flowchart.edge("E", "F")
flowchart.edge("F", "G")
flowchart.edge("G", "H")

# Add Iterative Improvement (dashed feedback loop)
flowchart.edge("H", "A", label="Iterative Improvement", style="dashed")

# Render and save the flowchart
flowchart.render("shneiderman_flowchart", cleanup=True)

# Display the generated diagram
from IPython.display import Image
Image("shneiderman_flowchart.png")
# Install required libraries (uncomment this for Google Colab or fresh environments)
# !pip install networkx matplotlib

import networkx as nx
import matplotlib.pyplot as plt

# Create a directed graph
G = nx.DiGraph()

# Add the central node
central_node = "Usability Heuristics"
G.add_node(central_node)

# Add heuristic principles as nodes and edges
heuristics = [
    "Visibility of System Status",
    "Match Between System and Real World",
    "User Control and Freedom",
    "Consistency and Standards",
    "Error Prevention",
    "Recognition Rather than Recall",
    "Flexibility and Efficiency of Use",
    "Aesthetic and Minimalist Design",
    "Help Users Recognize, Diagnose, and Recover from Errors",
    "Help and Documentation"
]

for heuristic in heuristics:
    G.add_node(heuristic)
    G.add_edge(central_node, heuristic)

# Draw the graph
plt.figure(figsize=(10, 10))
pos = nx.spring_layout(G, k=0.9)  # Layout for positioning nodes

# Draw nodes and edges
nx.draw(G, pos, with_labels=True, node_size=3000, node_color="skyblue", font_size=10, font_weight="bold", edge_color="gray")

# Add title
plt.title("Usability Heuristics Wheel", fontsize=14)
plt.show()
# Install matplotlib if not already installed (uncomment for Google Colab)
# !pip install matplotlib

import matplotlib.pyplot as plt

# Data for Garrett's Five Planes
planes = [
    {"name": "Strategy Plane\n(Why?)", "color": "#FBC02D"},
    {"name": "Scope Plane\n(What?)", "color": "#66BB6A"},
    {"name": "Structure Plane\n(How is it organized?)", "color": "#42A5F5"},
    {"name": "Skeleton Plane\n(How does it function?)", "color": "#EF5350"},
    {"name": "", "color": "#FBC02D"}  # Empty bottom border
]

# Plot configuration
fig, ax = plt.subplots(figsize=(8, 6))

# Draw rectangles for each plane
for i, plane in enumerate(planes):
    ax.add_patch(plt.Rectangle((0, i), 1, 1, color=plane["color"], ec="white"))
    if plane["name"]:  # Add text only if the plane name exists
        ax.text(0.5, i + 0.5, plane["name"], ha='center', va='center', fontsize=12, color='white')

# Adjust axis settings
ax.set_xlim(0, 1)
ax.set_ylim(0, len(planes))
ax.axis("off")  # Hide axes

# Title
plt.title("Garrett's Five Planes of User Experience", fontsize=14)

# Display the diagram
plt.show()
# Install matplotlib if not already installed (uncomment for Google Colab)
# !pip install matplotlib

import matplotlib.pyplot as plt

# Data for Garrett's Five Planes
planes = [
    {"name": "Strategy Plane\n(Why?)", "color": "#FBC02D"},
    {"name": "Scope Plane\n(What?)", "color": "#66BB6A"},
    {"name": "Structure Plane\n(How is it organized?)", "color": "#42A5F5"},
    {"name": "Skeleton Plane\n(How does it function?)", "color": "#EF5350"},
    {"name": "", "color": "#FBC02D"}  # Empty bottom border
]

# Plot configuration
fig, ax = plt.subplots(figsize=(8, 6))

# Draw rectangles for each plane
for i, plane in enumerate(planes):
    ax.add_patch(plt.Rectangle((0, i), 1, 1, color=plane["color"], ec="white"))
    if plane["name"]:  # Add text only if the plane name exists
        ax.text(0.5, i + 0.5, plane["name"], ha='center', va='center', fontsize=12, color='white')

# Adjust axis settings
ax.set_xlim(0, 1)
ax.set_ylim(0, len(planes))
ax.axis("off")  # Hide axes

# Title
plt.title("Garrett's Five Planes of User Experience", fontsize=14)

# Display the diagram
plt.show()
# Install graphviz (uncomment this in Google Colab or if not installed)
# !pip install graphviz

from graphviz import Digraph

# Initialize a directed graph
its_diagram = Digraph(comment='Intelligent Tutoring System Diagram', format='png')

# Define nodes
its_diagram.node("A", "Intelligent Tutoring System", shape="ellipse")
its_diagram.node("B", "User", shape="ellipse")
its_diagram.node("C", "Student", shape="ellipse")
its_diagram.node("D", "Tutor", shape="ellipse")
its_diagram.node("E", "Learning Materials", shape="ellipse")
its_diagram.node("F", "Assessment", shape="ellipse")
its_diagram.node("G", "Progress Tracking", shape="ellipse")
its_diagram.node("H", "Feedback", shape="ellipse")

# Add edges to represent relationships
its_diagram.edge("A", "B", "interacts with")
its_diagram.edge("B", "C", "is a")
its_diagram.edge("B", "D", "is a")
its_diagram.edge("A", "E", "provides")
its_diagram.edge("E", "F", "linked to")
its_diagram.edge("A", "G", "tracks")
its_diagram.edge("G", "H", "influences")
its_diagram.edge("A", "H", "delivers")
its_diagram.edge("E", "F", "administers")

# Render the diagram
its_diagram.render("its_diagram", cleanup=True)

# Display the diagram
from IPython.display import Image
Image("its_diagram.png")
